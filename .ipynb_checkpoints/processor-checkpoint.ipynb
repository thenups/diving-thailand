# %%
import xml.etree.ElementTree as ET
import pandas as pd

tree = ET.parse('data/Thailand_Dives.ssrf')
root = tree.getroot()

# %%
# Create list of all dive sites
sites = [child.attrib for child in root[1]]
sites
# Out:
# [{'uuid': '1fb33d15',
#   'name': 'Banana Bay - Racha Noi, Thailand',
#   'gps': '7.498778 98.324667'},
#  {'uuid': '20a60b7f',
#   'name': 'Palong Wall - Koh Phi Phi, Thailand',
#   'gps': '7.689509 98.765525'},
#  {'uuid': '80987779',
#   'name': 'Banana Rock - Racha Noi, Thailand',
#   'gps': '7.501408 98.327582'},
#  {'uuid': '96325c36',
#   'name': 'Twins - Koh Tao, Thailand',
#   'gps': '9.999084 99.779192'},
#  {'uuid': '974ece1b',
#   'name': 'Chumpong Rock - Koh Tao, Thailand',
#   'gps': '10.161833 99.784639'},
#  {'uuid': '9b660b50',
#   'name': 'Bay 1 - Racha Yai, Thailand',
#   'gps': '7.596972 98.370222'},
#  {'uuid': 'ab284c0b',
#   'name': 'White Rock - Koh Tao, Thailand',
#   'gps': '10.109806 99.813944'},
#  {'uuid': 'cd9a8def',
#   'name': 'Koh Bida Nok - Koh Phi Phi, Thailand',
#   'gps': '7.654055 98.766068'},
#  {'uuid': 'd62595ef',
#   'name': 'Turtle Rock - Phuket, Thailand',
#   'gps': '7.684868 98.763032'},
#  {'uuid': 'e6c1cd2b',
#   'name': 'Shark Point - Phuket, Thailand',
#   'gps': '7.749191 98.576700'},
#  {'uuid': 'eee3a5e0',
#   'name': 'Southwest Pinnacle - Koh Tao, Thailand',
#   'gps': '9.999084 99.779192'},
#  {'uuid': 'f77407b3',
#   'name': 'Sattakut Shipwreck - Koh Tao, Thailand',
#   'gps': '10.105583 99.813583'}]

# %%
# Function to 
def insertKeyValues(dictionary):
    d = {}
    
    # Keys to not include
    delete = ['rating','visibility','size','workpressure','description','model','last-manual-time','tags','depth']
    
    # Make sure correct values are stored
    for k, v in dictionary:
        if k not in delete:
            d[replaceKey(k)] = v
    
    return d

# Function to replace the key with the wanted key
def replaceKey(k):
    # All keys that need their name replaced
    keyChange = {
        'start':'start_pressure',
        'end':'end_pressure',
        'air': 'air_temp',
        'water': 'water_temp',
        'divesiteid':'uuid'
    }
    
    if k in keyChange.keys():
        return keyChange[k]
    else:
        return k

# %%
dives = []

# Get all site info
for dive in root[2]:
    # Create dictionary for the dive
    details = {}
    
    # Save keys for the attributes of the dive element itself
    details.update(insertKeyValues(dive.attrib.items()))
        
    # Subelement breakdown
    for d in dive:
    
        # Save information based on where it's stored in tree
        if d.tag in ['divemaster','buddy','notes','suit']:
            details[d.tag] = d.text
            
        else:
            # Save keys for subelements
            details.update(insertKeyValues(d.attrib.items()))
            
            # Save subelement child for Depth
            if d.tag == 'divecomputer':
                details['max_depth'] = d[0].attrib['max']
    
    # Appened details to list
    dives.append(details)

# %%
dives
# Out:
# [{'number': '1',
#   'uuid': 'cd9a8def',
#   'date': '2020-03-10',
#   'time': '09:54:00',
#   'duration': '51:00 min',
#   'divemaster': 'Tom Domville',
#   'buddy': 'Prithvi, Ravi',
#   'notes': 'Aussie Divers (PADI), Phuket\nCharter Boat Dive\n\nCurrent: miodre current\nViz: 3-4m\nAvg. Depth: \n\nFish:\nParrot fish, box fish, puffed fish, pipe fish, file fish, blue dragon nuddie, sea cucumbers, spiny lobster, shrimps, clownfish, lionfish, cleaner wrasse, banded snakes, moray eel, damsel fish, yellow back butterfly fish, angelfish, banner fish, moorish idol, crown of thorn sea start, blue star\n\nCoral:\nArella gorgonion, acropora elk horn coral (plate variety at 40ft depth), usmilia, anemone, porites, montipora',
#   'suit': '3mm, long wet',
#   'start_pressure': '220.0 bar',
#   'end_pressure': '90.0 bar',
#   'weight': '3.6 kg',
#   'air_temp': '31.0 C',
#   'water_temp': '27.0 C',
#   'max_depth': '17.9 m'},
#  {'number': '2',
#   'uuid': 'd62595ef',
#   'date': '2020-03-10',
#   'time': '11:53:00',
#   'duration': '53:00 min',
#   'divemaster': 'Tom Domville',
#   'buddy': 'Prithvi, Ravi',
#   'notes': 'Aussie Divers (PADI), Phuket\nCharter Boat Dive\n\nCurrent: No current, a few thermoclines\nViz: 6m\nAvg. Depth: \n\nFish:\nNudies everywhere! Damsel fish, spiny lobster, shrimp, moorish idol, blue fin trevelli (super long time), something that looked like a tang, magnificent war slug, harliquen?, godfrey’s sea cucumber, Durban dancing shrimp, reef crab, cowre, trevally, 2 banded snapper, black damsel fish, spotted box fish\n\nCoral:\nPorietes plate, montipora, acropora',
#   'suit': '3mm, long wet',
#   'start_pressure': '230.0 bar',
#   'end_pressure': '90.0 bar',
#   'weight': '3.4 kg',
#   'air_temp': '35.0 C',
#   'water_temp': '29.0 C',
#   'max_depth': '18.7 m'},
#  {'number': '3',
#   'uuid': 'e6c1cd2b',
#   'date': '2020-03-10',
#   'time': '14:16:00',
#   'duration': '50:00 min',
#   'divemaster': 'Tom Domville',
#   'buddy': 'Prithvi, Ravi',
#   'notes': 'Aussie Divers (PADI), Phuket\nCharter Boat Dive\n\nCurrent: very strong\nViz: 3m\nAvg. Depth: \n\nCoral:\nPorites, ctornella (harp coral genus), purple barrel sponge\n\nFish:\nOrange spike sea cucumber, pineapple sea cucumber, marbled sea cucumber, leopard shark, ghost pipe fish, painted spiny lobster, Pharo cuttle fish (genus sapia), blue stars, ocillated nuddie, yellow spotted clam, surgeon fish (lined), batfish, yellow box fullier, butterfly fish, barracuda (so many at the beginning), moray eel, cornefish',
#   'suit': '3mm, long wet',
#   'start_pressure': '210.0 bar',
#   'end_pressure': '70.0 bar',
#   'weight': '3.6 kg',
#   'air_temp': '37.0 C',
#   'water_temp': '29.0 C',
#   'max_depth': '15.8 m'},
#  {'number': '4',
#   'uuid': '20a60b7f',
#   'date': '2020-03-12',
#   'time': '09:57:07',
#   'duration': '52:00 min',
#   'divemaster': 'Tom Domville',
#   'buddy': 'Prithvi, Ravi',
#   'notes': 'Aussie Divers (PADI), Phuket\nCharter Boat Dive\n\nCurrent: \nViz: \nAvg. Depth: \n\nCoral:\nParieties, lots of coral eggs, Yellow sea can, gorgonian, giant purple barrel sponges, white sea fan\n\nFish:\nDurban Dancing shrimp, black tip reef shark, barracuda, hawksbill turtle, nudieeeees, wart slugs, moorish idols, stone fish, scorpion fish, fusiliers, box fish, moray eel, damselfish, angelfish',
#   'suit': '3mm, long wet',
#   'start_pressure': '210.0 bar',
#   'end_pressure': '70.0 bar',
#   'weight': '3.6 kg',
#   'air_temp': '30.0 C',
#   'water_temp': '28.0 C',
#   'max_depth': '18.8 m'},
#  {'number': '5',
#   'uuid': 'd62595ef',
#   'date': '2020-03-12',
#   'time': '11:48:41',
#   'duration': '52:00 min',
#   'divemaster': 'Tom Domville',
#   'buddy': 'Prithvi, Ravi',
#   'notes': 'Aussie Divers (PADI), Phuket\nCharter Boat Dive\n\nCurrent: Many thermoclines (between 26C & 29C)\nViz: 3-4m\nAvg. Depth: \n\nCoral:\nEusmilia, bright green boulder coral, parieties, purple barrel sponge\n\nFish:\nBlack tip reef shark, hawksbill turtle, feather star, crown of thorns, box fish, stone fish, grey trevali, schooling’s chevron barracuda, blue dragon nuddie, sea cucumbers, brittle star, blue star',
#   'suit': '3mm, long wet',
#   'start_pressure': '200.0 bar',
#   'end_pressure': '70.0 bar',
#   'weight': '3.6 kg',
#   'air_temp': '33.0 C',
#   'water_temp': '27.0 C',
#   'max_depth': '17.1 m'},
#  {'number': '6',
#   'uuid': 'e6c1cd2b',
#   'date': '2020-03-12',
#   'time': '14:06:15',
#   'duration': '48:00 min',
#   'divemaster': 'Tom Domville',
#   'buddy': 'Prithvi, Ravi',
#   'notes': 'Aussie Divers (PADI), Phuket\nCharter Boat Dive\n\nCurrent: medium, one or two cold thermoclines\nViz: 4m viz\nAvg. Depth: \n\nFish: \nLion fish, dwarf lion fish, wrasse, black spot damselfish, blue trevali, parrotfish, carp (one dying, one alive), leopard shark, moray eel, moorish idol, nuddie branch(1), trigger fish, copperhead butterfly fish, snapper, grouper, rabbit fish, soldier fish, schooling chevron barracuda, solo great barracuda, porcupine fish, swimming banded sea snake, loads of urchins \n\nCoral:\nBarrel sponge',
#   'suit': '3mm, long wet',
#   'start_pressure': '200.0 bar',
#   'end_pressure': '70.0 bar',
#   'weight': '3.6 kg',
#   'air_temp': '36.0 C',
#   'water_temp': '28.0 C',
#   'max_depth': '17.3 m'},
#  {'number': '7',
#   'uuid': '1fb33d15',
#   'date': '2020-03-14',
#   'time': '10:50:35',
#   'duration': '1:07 min',
#   'divemaster': 'Tom Domville',
#   'buddy': 'Ravi',
#   'notes': "Aussie Divers (PADI), Phuket\nCharter Boat Dive\n\nAborted dive due to shortness of breath caused my acid reflux. This was a very panicked abort as the feeling was unatural and it felt like I couldn't breathe even thought there was air coming through the regulator. Surfaced, was able to catch my breath, and decided to decent again.",
#   'suit': '3mm, long wet',
#   'weight': '3.6 kg',
#   'air_temp': '31.0 C',
#   'water_temp': '30.0 C',
#   'max_depth': '5.5 m'},
#  {'number': '7',
#   'uuid': '1fb33d15',
#   'date': '2020-03-14',
#   'time': '10:55:20',
#   'duration': '51:00 min',
#   'divemaster': 'Tom Domville',
#   'buddy': 'Ravi',
#   'notes': 'Aussie Divers (PADI), Phuket\nCharter Boat Dive\n\nCurrent: no current\nViz: 10m\nAvg Depth: 13.4m\n\nFish:\nTrumpet Fish\nHermit crab with harry legs\nFrog Fish\nPuffer fish - very large\nGoat Fish\nAngelfish (sexy time)\nStragged Damselfish',
#   'suit': '3mm, long wet',
#   'start_pressure': '190.0 bar',
#   'end_pressure': '70.0 bar',
#   'weight': '3.6 kg',
#   'air_temp': '31.0 C',
#   'water_temp': '29.0 C',
#   'max_depth': '23.0 m'},
#  {'number': '8',
#   'uuid': '80987779',
#   'date': '2020-03-14',
#   'time': '12:49:53',
#   'duration': '53:00 min',
#   'divemaster': 'Tom Domville',
#   'buddy': 'Ravi',
#   'notes': 'Aussie Divers (PADI), Phuket\nCharter Boat Dive\n\nCurrent: slight current, 2 degree thermocline \nViz: 6-8m \nAvg Depth: 13.4m\n\nFish:\nPharoe Cuttlefish\nDurbin Dancing Shrimp\nBlue Spotted Ray\nNuddies\nSea Cucumber\nGodfrey’s Sea Cumber\nTrevali (tail looked like Malaysia airlines, it was being serviced by lots of cleaner wrass)\nBlue Stars\nButterfly fish\nBox Fish\n\nCoral:\nSoft, Elkhorn (with blue tips), staghorms, Blue tipped coral',
#   'suit': '3mm, long wet',
#   'start_pressure': '200.0 bar',
#   'end_pressure': '80.0 bar',
#   'weight': '3.6 kg',
#   'air_temp': '33.0 C',
#   'water_temp': '28.0 C',
#   'max_depth': '19.4 m'},
#  {'number': '9',
#   'uuid': '9b660b50',
#   'date': '2020-03-14',
#   'time': '14:58:09',
#   'duration': '5:00 min',
#   'divemaster': 'Tom Domville',
#   'buddy': 'Ravi',
#   'notes': 'Aussie Divers (PADI), Phuket\nCharter Boat Dive\n\nHad a false start and had to surface right as we started decending. Later completely aborted dive due to shortness of breath caused my acid reflux. Much more controlled ascent this time. Decided to not continue diving.\n\nSite Info:\nReef was ruined after tsunami\nIn 2015-2016, 1 boat and several cubes were scuttled for training. The area is now home to schooling fish and baby coral. The\nsunken ship is named "The Haroumi"',
#   'suit': '3mm, long wet',
#   'weight': '3.6 kg',
#   'air_temp': '36.0 C',
#   'water_temp': '30.0 C',
#   'max_depth': '10.7 m'},
#  {'number': '10',
#   'uuid': '974ece1b',
#   'date': '2020-03-17',
#   'time': '14:18:38',
#   'duration': '46:00 min',
#   'divemaster': 'Liz',
#   'buddy': 'Prithvi, Ravi',
#   'notes': 'Hydronauts (RAID), Koh Tao\nBoat Dive - rented dive boat with other schools\n\nViz: 10m\nAvg Depth: 15.8m\nGear: Shark Skin Suit (full-zip top, full pants), wings, 2 meter octopus with backup bungeed around neck\n\nFish:\nParrot Fish, Cleaner wrasse, huge groupers, wart slug, school of baby barracuda (yellow tail) , angel fish large, moorish idols (large), damsel fish (large), hermit crab, Christmas tree worms, beaked coral fish, sargeant major fish, urchins, oysters, giant clams, fusiliers, sea cucumber \n\nCoral:\nAcrophora (staghorn coral), pore coral, parieties, leptoria, barrel sponge',
#   'suit': 'Shark Skin full-zip top, Shark Skin pants',
#   'start_pressure': '190.0 bar',
#   'end_pressure': '50.0 bar',
#   'weight': '2.0 kg',
#   'air_temp': '28.0 C',
#   'water_temp': '29.0 C',
#   'max_depth': '25.1 m'},
#  {'number': '11',
#   'uuid': 'ab284c0b',
#   'date': '2020-03-17',
#   'time': '14:28:17',
#   'duration': '62:00 min',
#   'divemaster': 'Liz',
#   'buddy': 'Ravi, Prithvi',
#   'notes': 'Hydronauts (RAID), Koh Tao\nBoat Dive - rented dive boat with other schools\n\nViz: 4-5m\nAvg Depth: 10.4m\nGear: Shark Skin Suit (full-zip top, full pants), wings, 2 meter octopus with backup bungeed around neck\n\nFish:\nBlue spotted ribbon tail ray, golden travail, moorish idol, butterfly fish, sergeant major fish, puffer fish, file fish, damsel fish, angel fish, varicose sea slug, soldier fish, grouper, trigger fish(?), squirrel fish, gobi, snapper, Christmas tree worms (sooooooo many) \n\nCoral: \nEggs, elk horn coral, table coral, stag horn coral, boulder coral, barrel sponge,',
#   'suit': 'Shark Skin full-zip top, Shark Skin pants',
#   'start_pressure': '200.0 bar',
#   'end_pressure': '80.0 bar',
#   'weight': '2.0 kg',
#   'air_temp': '30.0 C',
#   'water_temp': '29.0 C',
#   'max_depth': '18.5 m'},
#  {'number': '12',
#   'uuid': 'f77407b3',
#   'date': '2020-03-18',
#   'time': '07:29:08',
#   'duration': '50:00 min',
#   'divemaster': 'Genis Mir (51986)',
#   'buddy': 'Prithvi, Ravi',
#   'notes': 'LBD™ - La Bombona Diving™ (RAID), Koh Tao\nBoat Dive - semi-private triple decker boat\n\nViz: 3-5m\nAvg Depth: 15.5m\nGear: wings\n\nFish:\nStriped Remora (swimming around us by itself at the beginning as we descended)\nLong nosed (faced) emperor fish\nOne Spot/Black Spot Snapper\nCrab\nAngelfish\nAnemone Fish\nBlack spotted puffer\nPipe Fish\nLong-snout Clingfish\n2 large groupers (in captains caban)\nButterfly Fish\nSoldier Fish\nBlue Lip fish that eat sea urchins\nChristmas Tree Worm\n\nCoral:\nAcrophora\nTable Coral\n\nSurface Interval: squid/cuttefish',
#   'suit': '3mm, short wet',
#   'start_pressure': '200.0 bar',
#   'end_pressure': '80.0 bar',
#   'weight': '3.0 kg',
#   'air_temp': '28.0 C',
#   'water_temp': '29.0 C',
#   'max_depth': '28.0 m'},
#  {'number': '13',
#   'uuid': 'ab284c0b',
#   'date': '2020-03-18',
#   'time': '09:25:02',
#   'duration': '63:00 min',
#   'divemaster': 'Genis Mir (51986)',
#   'buddy': 'Prithvi, Ravi',
#   'notes': 'LBD™ - La Bombona Diving™ (RAID), Koh Tao\nBoat Dive - semi-private triple decker boat\n\nViz: 5-10m\nAvg Depth: 10.8m\nGear: wings\n\nFish:\nStriped Remora (swimming around us by itself at the beginning as we descended)\nLong nosed (faced) emperor fish\nOne Spot/Black Spot Snapper\nCrab\nAngelfish\nAnemone Fish\nBlack spotted puffer\nPipe Fish\nLong-snout Clingfish\n2 large groupers (in captains caban)\nButterfly Fish\nSoldier Fish\nBlue Lip fish that eat sea urchins\nChristmas Tree Worm\n\nCoral:\nAcrophora\nTable Coral',
#   'suit': '3mm, short wet',
#   'start_pressure': '190.0 bar',
#   'end_pressure': '70.0 bar',
#   'weight': '3.0 kg',
#   'air_temp': '28.0 C',
#   'water_temp': '29.0 C',
#   'max_depth': '16.8 m'},
#  {'number': '14',
#   'uuid': 'eee3a5e0',
#   'date': '2020-03-19',
#   'time': '08:20:00',
#   'duration': '59:00 min',
#   'divemaster': 'Emile',
#   'buddy': 'Ravi, Prithvi',
#   'notes': 'Seashells Dive Resort, Koh Tao\nBoat Dive - private double decker boat\n\nViz: 10m\nAvg Depth: \n\nFish:\nGiant Groupers (super giant)\nBlue spotted ribbon tail rays\nDamselfish\nAngelfish\nTriggerfish (very territorial)\nWart slug\nHermit crab\nBlack Spot Porcupine fish\nYellow tail baby schooling barracuda \nParrotfish\nClams (walls full)\n\nCoral:\nGorgonian fans, carrot coral, stag horn',
#   'suit': '3mm, short wet',
#   'start_pressure': '200.0 bar',
#   'end_pressure': '50.0 bar',
#   'weight': '3.0 kg',
#   'air_temp': '28.0 C',
#   'water_temp': '29.0 C',
#   'max_depth': '25.0 m'},
#  {'number': '15',
#   'uuid': '96325c36',
#   'date': '2020-03-19',
#   'time': '12:02:06',
#   'duration': '44:00 min',
#   'divemaster': 'Emile',
#   'buddy': 'Ravi, Prithvi',
#   'notes': 'Seashells Dive Resort, Koh Tao\nBoat Dive - private double decker boat\n\nViz: 4-5m\nAvg Depth: \n\nStruggled a lot with my breathing on this one, very panicked\n\nFish:\nClams\nTrigger fish (got chased by one)\nParrot fish\nAnemone\nGiant Cowries\nSargeant majors\nSquirrelfish\nChristmas tree worms\nBoring clam\nPipe fish (hiding in stag horn coral)\nClownfish family (“Nemo’s” patch)\n\nCoral:\nPorites, Acropora, Boulder coral, Stag horn coral',
#   'suit': '3mm, short wet',
#   'start_pressure': '200.0 bar',
#   'end_pressure': '100.0 bar',
#   'weight': '3.0 kg',
#   'air_temp': '29.0 C',
#   'water_temp': '29.0 C',
#   'max_depth': '17.5 m'}]

# %%
# Create DF's from dictionaries
dfDive = pd.DataFrame(dives)
dfDive['number'] = pd.to_numeric(dfDive["number"])

dfSite = pd.DataFrame(sites)
dfSite.columns = ['uuid', 'site', 'gps'] #Rename columns

# %%
dfDive.head()
# Out:
#    number      uuid        date      time   duration    divemaster  \
# 0       1  cd9a8def  2020-03-10  09:54:00  51:00 min  Tom Domville
# 1       2  d62595ef  2020-03-10  11:53:00  53:00 min  Tom Domville
# 2       3  e6c1cd2b  2020-03-10  14:16:00  50:00 min  Tom Domville
# 3       4  20a60b7f  2020-03-12  09:57:07  52:00 min  Tom Domville
# 4       5  d62595ef  2020-03-12  11:48:41  52:00 min  Tom Domville
#
#            buddy                                              notes  \
# 0  Prithvi, Ravi  Aussie Divers (PADI), Phuket\nCharter Boat Div...
# 1  Prithvi, Ravi  Aussie Divers (PADI), Phuket\nCharter Boat Div...
# 2  Prithvi, Ravi  Aussie Divers (PADI), Phuket\nCharter Boat Div...
# 3  Prithvi, Ravi  Aussie Divers (PADI), Phuket\nCharter Boat Div...
# 4  Prithvi, Ravi  Aussie Divers (PADI), Phuket\nCharter Boat Div...
#
#             suit start_pressure end_pressure  weight air_temp water_temp  \
# 0  3mm, long wet      220.0 bar     90.0 bar  3.6 kg   31.0 C     27.0 C
# 1  3mm, long wet      230.0 bar     90.0 bar  3.4 kg   35.0 C     29.0 C
# 2  3mm, long wet      210.0 bar     70.0 bar  3.6 kg   37.0 C     29.0 C
# 3  3mm, long wet      210.0 bar     70.0 bar  3.6 kg   30.0 C     28.0 C
# 4  3mm, long wet      200.0 bar     70.0 bar  3.6 kg   33.0 C     27.0 C
#
#   max_depth
# 0    17.9 m
# 1    18.7 m
# 2    15.8 m
# 3    18.8 m
# 4    17.1 m

# %%
dfSite.head()
# Out:
#        uuid                                 site                  gps
# 0  1fb33d15     Banana Bay - Racha Noi, Thailand   7.498778 98.324667
# 1  20a60b7f  Palong Wall - Koh Phi Phi, Thailand   7.689509 98.765525
# 2  80987779    Banana Rock - Racha Noi, Thailand   7.501408 98.327582
# 3  96325c36            Twins - Koh Tao, Thailand   9.999084 99.779192
# 4  974ece1b    Chumpong Rock - Koh Tao, Thailand  10.161833 99.784639

# %%
# Take in duration column and make it into an int 
def createMinutes(series, splitV):
    ls = []
    
    for i in dfMerged['duration']:
        sp = i.split(splitV) #split string at based on determined string
        ls.append(int(sp[0])) #save first index as int
    
    return ls

# %%
# Merge DFs and sort by dive number
dfMerged = pd.merge(dfDive, dfSite, on='uuid', how='outer')
dfMerged = dfMerged.sort_values(by=['number'])
dfMerged = dfMerged.reset_index(drop=True)

# Make duration int
dfMerged['duration_min'] = createMinutes(dfMerged['duration'],':')

# Drop UUID column
dfMerged = dfMerged.drop(['uuid'], axis=1)
dfMerged = dfMerged.drop(['duration'], axis=1)

# Reorder columns
dfMerged = dfMerged[['number', 'date', 'time', 'site', 'gps', 'duration_min',
         'max_depth', 'divemaster', 'buddy', 'suit', 'weight', 'start_pressure',
         'end_pressure', 'air_temp', 'water_temp', 'notes']]

# %%
dfMerged.head()
# Out:
#    number        date      time                                  site  \
# 0       1  2020-03-10  09:54:00  Koh Bida Nok - Koh Phi Phi, Thailand
# 1       2  2020-03-10  11:53:00        Turtle Rock - Phuket, Thailand
# 2       3  2020-03-10  14:16:00        Shark Point - Phuket, Thailand
# 3       4  2020-03-12  09:57:07   Palong Wall - Koh Phi Phi, Thailand
# 4       5  2020-03-12  11:48:41        Turtle Rock - Phuket, Thailand
#
#                   gps  duration_min max_depth    divemaster          buddy  \
# 0  7.654055 98.766068            51    17.9 m  Tom Domville  Prithvi, Ravi
# 1  7.684868 98.763032            53    18.7 m  Tom Domville  Prithvi, Ravi
# 2  7.749191 98.576700            50    15.8 m  Tom Domville  Prithvi, Ravi
# 3  7.689509 98.765525            52    18.8 m  Tom Domville  Prithvi, Ravi
# 4  7.684868 98.763032            52    17.1 m  Tom Domville  Prithvi, Ravi
#
#             suit  weight start_pressure end_pressure air_temp water_temp  \
# 0  3mm, long wet  3.6 kg      220.0 bar     90.0 bar   31.0 C     27.0 C
# 1  3mm, long wet  3.4 kg      230.0 bar     90.0 bar   35.0 C     29.0 C
# 2  3mm, long wet  3.6 kg      210.0 bar     70.0 bar   37.0 C     29.0 C
# 3  3mm, long wet  3.6 kg      210.0 bar     70.0 bar   30.0 C     28.0 C
# 4  3mm, long wet  3.6 kg      200.0 bar     70.0 bar   33.0 C     27.0 C
#
#                                                notes
# 0  Aussie Divers (PADI), Phuket\nCharter Boat Div...
# 1  Aussie Divers (PADI), Phuket\nCharter Boat Div...
# 2  Aussie Divers (PADI), Phuket\nCharter Boat Div...
# 3  Aussie Divers (PADI), Phuket\nCharter Boat Div...
# 4  Aussie Divers (PADI), Phuket\nCharter Boat Div...

# %%
dfSelected = dfMerged.loc[dfMerged['duration_min'] > 5]
dfSelected.head()
# Out:
#    number        date      time                                  site  \
# 0       1  2020-03-10  09:54:00  Koh Bida Nok - Koh Phi Phi, Thailand
# 1       2  2020-03-10  11:53:00        Turtle Rock - Phuket, Thailand
# 2       3  2020-03-10  14:16:00        Shark Point - Phuket, Thailand
# 3       4  2020-03-12  09:57:07   Palong Wall - Koh Phi Phi, Thailand
# 4       5  2020-03-12  11:48:41        Turtle Rock - Phuket, Thailand
#
#                   gps  duration_min max_depth    divemaster          buddy  \
# 0  7.654055 98.766068            51    17.9 m  Tom Domville  Prithvi, Ravi
# 1  7.684868 98.763032            53    18.7 m  Tom Domville  Prithvi, Ravi
# 2  7.749191 98.576700            50    15.8 m  Tom Domville  Prithvi, Ravi
# 3  7.689509 98.765525            52    18.8 m  Tom Domville  Prithvi, Ravi
# 4  7.684868 98.763032            52    17.1 m  Tom Domville  Prithvi, Ravi
#
#             suit  weight start_pressure end_pressure air_temp water_temp  \
# 0  3mm, long wet  3.6 kg      220.0 bar     90.0 bar   31.0 C     27.0 C
# 1  3mm, long wet  3.4 kg      230.0 bar     90.0 bar   35.0 C     29.0 C
# 2  3mm, long wet  3.6 kg      210.0 bar     70.0 bar   37.0 C     29.0 C
# 3  3mm, long wet  3.6 kg      210.0 bar     70.0 bar   30.0 C     28.0 C
# 4  3mm, long wet  3.6 kg      200.0 bar     70.0 bar   33.0 C     27.0 C
#
#                                                notes
# 0  Aussie Divers (PADI), Phuket\nCharter Boat Div...
# 1  Aussie Divers (PADI), Phuket\nCharter Boat Div...
# 2  Aussie Divers (PADI), Phuket\nCharter Boat Div...
# 3  Aussie Divers (PADI), Phuket\nCharter Boat Div...
# 4  Aussie Divers (PADI), Phuket\nCharter Boat Div...

# %%
# Function to return dictionary with all wildlife in it
def wildlifeDict (listOfStrings):
    cleaned = []
    
    # Strip trailing spaces
    for l in listOfStrings:
        cleaned.append(l.rstrip())
        
    # Save indexes for fish and coral so we can compare which came first
    if 'Fish:' in cleaned:
        fish = cleaned.index('Fish:')
    else: fish = 0
    if 'Coral:' in cleaned:
        coral = cleaned.index('Coral:')
    else: coral = 0
    
    # See which value is higher and save all subsequent lines as a string
    if fish>0 and coral > fish:
        return wildlifeString(cleaned,fish,coral)
    elif coral>0 and fish > coral:
        return wildlifeString(cleaned,coral,fish)
    else: # if neither exists
        return {}

# Function to breakdown wildlife strings and separate them into fish or coral
def wildlifeString (listOfStrings, firsti, secondi):
    d = {}
    ls1 = []
    ls2 = []
    
    # What to do with the first value (which is the larger one)
    for i in range(firsti+1, secondi-1):
        # If there is a break, stop loop
        if listOfStrings[i] == '':
            break

        # add items to list
        else:
            ls1.append(listOfStrings[i])
        
        # add list to dict as joint string
        d[listOfStrings[firsti]] = ', '.join(ls1)


    # What to do with the lower value
    for i in range(secondi+1, len(listOfStrings)):

        # If there is a break, stop loop
        if listOfStrings[i] == '':
            break

        # add items to list
        else:
            ls2.append(listOfStrings[i])
        
        # add list to dict as joint string
        d[listOfStrings[secondi]] = ', '.join(ls2)
    
    # Return dictionary
    return(d)

# %%
allNotes = []

for notes in dfSelected['notes']:   

    d = {}
    
    # split string into 
    notes = notes.split('\n')
    
    # First line is always shop information
    d['shop'] = notes[0]
    
    # Find viz and current information in list
    i = 1
    while i < len(notes):
        if 'Current: ' in notes[i]:
            d['current'] = notes[i].split('Current: ')[1]

        if 'Viz: ' in notes[i]:
            d['viz'] = notes[i].split('Viz: ')[1]

        i += 1
    
    # Get all wildlife information
    d.update(wildlifeDict(notes))
    
    # Append to all notes list
    allNotes.append(d)

# %%
allNotes
# Out:
# [{'shop': 'Aussie Divers (PADI), Phuket',
#   'current': 'miodre current',
#   'viz': '3-4m',
#   'Fish:': 'Parrot fish, box fish, puffed fish, pipe fish, file fish, blue dragon nuddie, sea cucumbers, spiny lobster, shrimps, clownfish, lionfish, cleaner wrasse, banded snakes, moray eel, damsel fish, yellow back butterfly fish, angelfish, banner fish, moorish idol, crown of thorn sea start, blue star',
#   'Coral:': 'Arella gorgonion, acropora elk horn coral (plate variety at 40ft depth), usmilia, anemone, porites, montipora'},
#  {'shop': 'Aussie Divers (PADI), Phuket',
#   'current': 'No current, a few thermoclines',
#   'viz': '6m',
#   'Fish:': 'Nudies everywhere! Damsel fish, spiny lobster, shrimp, moorish idol, blue fin trevelli (super long time), something that looked like a tang, magnificent war slug, harliquen?, godfrey’s sea cucumber, Durban dancing shrimp, reef crab, cowre, trevally, 2 banded snapper, black damsel fish, spotted box fish',
#   'Coral:': 'Porietes plate, montipora, acropora'},
#  {'shop': 'Aussie Divers (PADI), Phuket',
#   'current': 'very strong',
#   'viz': '3m',
#   'Coral:': 'Porites, ctornella (harp coral genus), purple barrel sponge',
#   'Fish:': 'Orange spike sea cucumber, pineapple sea cucumber, marbled sea cucumber, leopard shark, ghost pipe fish, painted spiny lobster, Pharo cuttle fish (genus sapia), blue stars, ocillated nuddie, yellow spotted clam, surgeon fish (lined), batfish, yellow box fullier, butterfly fish, barracuda (so many at the beginning), moray eel, cornefish'},
#  {'shop': 'Aussie Divers (PADI), Phuket',
#   'current': '',
#   'viz': '',
#   'Coral:': 'Parieties, lots of coral eggs, Yellow sea can, gorgonian, giant purple barrel sponges, white sea fan',
#   'Fish:': 'Durban Dancing shrimp, black tip reef shark, barracuda, hawksbill turtle, nudieeeees, wart slugs, moorish idols, stone fish, scorpion fish, fusiliers, box fish, moray eel, damselfish, angelfish'},
#  {'shop': 'Aussie Divers (PADI), Phuket',
#   'current': 'Many thermoclines (between 26C & 29C)',
#   'viz': '3-4m',
#   'Coral:': 'Eusmilia, bright green boulder coral, parieties, purple barrel sponge',
#   'Fish:': 'Black tip reef shark, hawksbill turtle, feather star, crown of thorns, box fish, stone fish, grey trevali, schooling’s chevron barracuda, blue dragon nuddie, sea cucumbers, brittle star, blue star'},
#  {'shop': 'Aussie Divers (PADI), Phuket',
#   'current': 'medium, one or two cold thermoclines',
#   'viz': '4m viz',
#   'Fish:': 'Lion fish, dwarf lion fish, wrasse, black spot damselfish, blue trevali, parrotfish, carp (one dying, one alive), leopard shark, moray eel, moorish idol, nuddie branch(1), trigger fish, copperhead butterfly fish, snapper, grouper, rabbit fish, soldier fish, schooling chevron barracuda, solo great barracuda, porcupine fish, swimming banded sea snake, loads of urchins',
#   'Coral:': 'Barrel sponge'},
#  {'shop': 'Aussie Divers (PADI), Phuket',
#   'current': 'no current',
#   'viz': '10m'},
#  {'shop': 'Aussie Divers (PADI), Phuket',
#   'current': 'slight current, 2 degree thermocline ',
#   'viz': '6-8m ',
#   'Fish:': 'Pharoe Cuttlefish, Durbin Dancing Shrimp, Blue Spotted Ray, Nuddies, Sea Cucumber, Godfrey’s Sea Cumber, Trevali (tail looked like Malaysia airlines, it was being serviced by lots of cleaner wrass), Blue Stars, Butterfly fish, Box Fish',
#   'Coral:': 'Soft, Elkhorn (with blue tips), staghorms, Blue tipped coral'},
#  {'shop': 'Hydronauts (RAID), Koh Tao',
#   'viz': '10m',
#   'Fish:': 'Parrot Fish, Cleaner wrasse, huge groupers, wart slug, school of baby barracuda (yellow tail) , angel fish large, moorish idols (large), damsel fish (large), hermit crab, Christmas tree worms, beaked coral fish, sargeant major fish, urchins, oysters, giant clams, fusiliers, sea cucumber',
#   'Coral:': 'Acrophora (staghorn coral), pore coral, parieties, leptoria, barrel sponge'},
#  {'shop': 'Hydronauts (RAID), Koh Tao',
#   'viz': '4-5m',
#   'Fish:': 'Blue spotted ribbon tail ray, golden travail, moorish idol, butterfly fish, sergeant major fish, puffer fish, file fish, damsel fish, angel fish, varicose sea slug, soldier fish, grouper, trigger fish(?), squirrel fish, gobi, snapper, Christmas tree worms (sooooooo many)',
#   'Coral:': 'Eggs, elk horn coral, table coral, stag horn coral, boulder coral, barrel sponge,'},
#  {'shop': 'LBD™ - La Bombona Diving™ (RAID), Koh Tao',
#   'viz': '3-5m',
#   'Fish:': 'Striped Remora (swimming around us by itself at the beginning as we descended), Long nosed (faced) emperor fish, One Spot/Black Spot Snapper, Crab, Angelfish, Anemone Fish, Black spotted puffer, Pipe Fish, Long-snout Clingfish, 2 large groupers (in captains caban), Butterfly Fish, Soldier Fish, Blue Lip fish that eat sea urchins, Christmas Tree Worm',
#   'Coral:': 'Acrophora, Table Coral'},
#  {'shop': 'LBD™ - La Bombona Diving™ (RAID), Koh Tao',
#   'viz': '5-10m',
#   'Fish:': 'Striped Remora (swimming around us by itself at the beginning as we descended), Long nosed (faced) emperor fish, One Spot/Black Spot Snapper, Crab, Angelfish, Anemone Fish, Black spotted puffer, Pipe Fish, Long-snout Clingfish, 2 large groupers (in captains caban), Butterfly Fish, Soldier Fish, Blue Lip fish that eat sea urchins, Christmas Tree Worm',
#   'Coral:': 'Acrophora, Table Coral'},
#  {'shop': 'Seashells Dive Resort, Koh Tao',
#   'viz': '10m',
#   'Fish:': 'Giant Groupers (super giant), Blue spotted ribbon tail rays, Damselfish, Angelfish, Triggerfish (very territorial), Wart slug, Hermit crab, Black Spot Porcupine fish, Yellow tail baby schooling barracuda, Parrotfish, Clams (walls full)',
#   'Coral:': 'Gorgonian fans, carrot coral, stag horn'},
#  {'shop': 'Seashells Dive Resort, Koh Tao',
#   'viz': '4-5m',
#   'Fish:': 'Clams, Trigger fish (got chased by one), Parrot fish, Anemone, Giant Cowries, Sargeant majors, Squirrelfish, Christmas tree worms, Boring clam, Pipe fish (hiding in stag horn coral), Clownfish family (“Nemo’s” patch)',
#   'Coral:': 'Porites, Acropora, Boulder coral, Stag horn coral'}]

# %%
dfNote = pd.DataFrame(allNotes)
dfNote.columns = ['shop', 'current', 'viz', 'fish', 'coral']
dfNote.head()
# Out:
#                            shop                                current   viz  \
# 0  Aussie Divers (PADI), Phuket                         miodre current  3-4m
# 1  Aussie Divers (PADI), Phuket         No current, a few thermoclines    6m
# 2  Aussie Divers (PADI), Phuket                            very strong    3m
# 3  Aussie Divers (PADI), Phuket
# 4  Aussie Divers (PADI), Phuket  Many thermoclines (between 26C & 29C)  3-4m
#
#                                                 fish  \
# 0  Parrot fish, box fish, puffed fish, pipe fish,...
# 1  Nudies everywhere! Damsel fish, spiny lobster,...
# 2  Orange spike sea cucumber, pineapple sea cucum...
# 3  Durban Dancing shrimp, black tip reef shark, b...
# 4  Black tip reef shark, hawksbill turtle, feathe...
#
#                                                coral
# 0  Arella gorgonion, acropora elk horn coral (pla...
# 1                Porietes plate, montipora, acropora
# 2  Porites, ctornella (harp coral genus), purple ...
# 3  Parieties, lots of coral eggs, Yellow sea can,...
# 4  Eusmilia, bright green boulder coral, parietie...

# %%
df = pd.merge(dfSelected, dfNote, left_index=True, right_index=True)
df = df.drop(['notes'], axis=1)
df = df[['number', 'date', 'time', 
       'shop', 'divemaster', 'buddy', 'suit', 'weight', 'site', 
       'gps', 'duration_min', 'max_depth', 'start_pressure',
       'end_pressure', 'air_temp', 'water_temp', 'current', 'viz',
       'fish', 'coral']]
df
# Out:
#     number        date      time                                       shop  \
# 0        1  2020-03-10  09:54:00               Aussie Divers (PADI), Phuket
# 1        2  2020-03-10  11:53:00               Aussie Divers (PADI), Phuket
# 2        3  2020-03-10  14:16:00               Aussie Divers (PADI), Phuket
# 3        4  2020-03-12  09:57:07               Aussie Divers (PADI), Phuket
# 4        5  2020-03-12  11:48:41               Aussie Divers (PADI), Phuket
# 5        6  2020-03-12  14:06:15               Aussie Divers (PADI), Phuket
# 7        7  2020-03-14  10:55:20               Aussie Divers (PADI), Phuket
# 8        8  2020-03-14  12:49:53                 Hydronauts (RAID), Koh Tao
# 10      10  2020-03-17  14:18:38  LBD™ - La Bombona Diving™ (RAID), Koh Tao
# 11      11  2020-03-17  14:28:17  LBD™ - La Bombona Diving™ (RAID), Koh Tao
# 12      12  2020-03-18  07:29:08             Seashells Dive Resort, Koh Tao
# 13      13  2020-03-18  09:25:02             Seashells Dive Resort, Koh Tao
#
#            divemaster          buddy  \
# 0        Tom Domville  Prithvi, Ravi
# 1        Tom Domville  Prithvi, Ravi
# 2        Tom Domville  Prithvi, Ravi
# 3        Tom Domville  Prithvi, Ravi
# 4        Tom Domville  Prithvi, Ravi
# 5        Tom Domville  Prithvi, Ravi
# 7        Tom Domville           Ravi
# 8        Tom Domville           Ravi
# 10                Liz  Prithvi, Ravi
# 11                Liz  Ravi, Prithvi
# 12  Genis Mir (51986)  Prithvi, Ravi
# 13  Genis Mir (51986)  Prithvi, Ravi
#
#                                          suit  weight  \
# 0                               3mm, long wet  3.6 kg
# 1                               3mm, long wet  3.4 kg
# 2                               3mm, long wet  3.6 kg
# 3                               3mm, long wet  3.6 kg
# 4                               3mm, long wet  3.6 kg
# 5                               3mm, long wet  3.6 kg
# 7                               3mm, long wet  3.6 kg
# 8                               3mm, long wet  3.6 kg
# 10  Shark Skin full-zip top, Shark Skin pants  2.0 kg
# 11  Shark Skin full-zip top, Shark Skin pants  2.0 kg
# 12                             3mm, short wet  3.0 kg
# 13                             3mm, short wet  3.0 kg
#
#                                       site                  gps  duration_min  \
# 0     Koh Bida Nok - Koh Phi Phi, Thailand   7.654055 98.766068            51
# 1           Turtle Rock - Phuket, Thailand   7.684868 98.763032            53
# 2           Shark Point - Phuket, Thailand   7.749191 98.576700            50
# 3      Palong Wall - Koh Phi Phi, Thailand   7.689509 98.765525            52
# 4           Turtle Rock - Phuket, Thailand   7.684868 98.763032            52
# 5           Shark Point - Phuket, Thailand   7.749191 98.576700            48
# 7         Banana Bay - Racha Noi, Thailand   7.498778 98.324667            51
# 8        Banana Rock - Racha Noi, Thailand   7.501408 98.327582            53
# 10       Chumpong Rock - Koh Tao, Thailand  10.161833 99.784639            46
# 11          White Rock - Koh Tao, Thailand  10.109806 99.813944            62
# 12  Sattakut Shipwreck - Koh Tao, Thailand  10.105583 99.813583            50
# 13          White Rock - Koh Tao, Thailand  10.109806 99.813944            63
#
#    max_depth start_pressure end_pressure air_temp water_temp  \
# 0     17.9 m      220.0 bar     90.0 bar   31.0 C     27.0 C
# 1     18.7 m      230.0 bar     90.0 bar   35.0 C     29.0 C
# 2     15.8 m      210.0 bar     70.0 bar   37.0 C     29.0 C
# 3     18.8 m      210.0 bar     70.0 bar   30.0 C     28.0 C
# 4     17.1 m      200.0 bar     70.0 bar   33.0 C     27.0 C
# 5     17.3 m      200.0 bar     70.0 bar   36.0 C     28.0 C
# 7     23.0 m      190.0 bar     70.0 bar   31.0 C     29.0 C
# 8     19.4 m      200.0 bar     80.0 bar   33.0 C     28.0 C
# 10    25.1 m      190.0 bar     50.0 bar   28.0 C     29.0 C
# 11    18.5 m      200.0 bar     80.0 bar   30.0 C     29.0 C
# 12    28.0 m      200.0 bar     80.0 bar   28.0 C     29.0 C
# 13    16.8 m      190.0 bar     70.0 bar   28.0 C     29.0 C
#
#                                   current     viz  \
# 0                          miodre current    3-4m
# 1          No current, a few thermoclines      6m
# 2                             very strong      3m
# 3
# 4   Many thermoclines (between 26C & 29C)    3-4m
# 5    medium, one or two cold thermoclines  4m viz
# 7   slight current, 2 degree thermocline    6-8m
# 8                                     NaN     10m
# 10                                    NaN    3-5m
# 11                                    NaN   5-10m
# 12                                    NaN     10m
# 13                                    NaN    4-5m
#
#                                                  fish  \
# 0   Parrot fish, box fish, puffed fish, pipe fish,...
# 1   Nudies everywhere! Damsel fish, spiny lobster,...
# 2   Orange spike sea cucumber, pineapple sea cucum...
# 3   Durban Dancing shrimp, black tip reef shark, b...
# 4   Black tip reef shark, hawksbill turtle, feathe...
# 5   Lion fish, dwarf lion fish, wrasse, black spot...
# 7   Pharoe Cuttlefish, Durbin Dancing Shrimp, Blue...
# 8   Parrot Fish, Cleaner wrasse, huge groupers, wa...
# 10  Striped Remora (swimming around us by itself a...
# 11  Striped Remora (swimming around us by itself a...
# 12  Giant Groupers (super giant), Blue spotted rib...
# 13  Clams, Trigger fish (got chased by one), Parro...
#
#                                                 coral
# 0   Arella gorgonion, acropora elk horn coral (pla...
# 1                 Porietes plate, montipora, acropora
# 2   Porites, ctornella (harp coral genus), purple ...
# 3   Parieties, lots of coral eggs, Yellow sea can,...
# 4   Eusmilia, bright green boulder coral, parietie...
# 5                                       Barrel sponge
# 7   Soft, Elkhorn (with blue tips), staghorms, Blu...
# 8   Acrophora (staghorn coral), pore coral, pariet...
# 10                             Acrophora, Table Coral
# 11                             Acrophora, Table Coral
# 12            Gorgonian fans, carrot coral, stag horn
# 13  Porites, Acropora, Boulder coral, Stag horn coral

# %%
df.to_excel("dives_thailand.xlsx", sheet_name='dives')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-26-a3ad1a5c87ba> in <module>
# ----> 1 df.to_excel("dives_thailand.xlsx", sheet_name='dives')
#
# /usr/local/lib/python3.7/site-packages/pandas/core/generic.py in to_excel(self, excel_writer, sheet_name, na_rep, float_format, columns, header, index, index_label, startrow, startcol, engine, merge_cells, encoding, inf_rep, verbose, freeze_panes)
#    2179             startcol=startcol,
#    2180             freeze_panes=freeze_panes,
# -> 2181             engine=engine,
#    2182         )
#    2183
#
# /usr/local/lib/python3.7/site-packages/pandas/io/formats/excel.py in write(self, writer, sheet_name, startrow, startcol, freeze_panes, engine)
#     724             need_save = False
#     725         else:
# --> 726             writer = ExcelWriter(stringify_path(writer), engine=engine)
#     727             need_save = True
#     728
#
# /usr/local/lib/python3.7/site-packages/pandas/io/excel/_openpyxl.py in __init__(self, path, engine, mode, **engine_kwargs)
#      16     def __init__(self, path, engine=None, mode="w", **engine_kwargs):
#      17         # Use the openpyxl module as the Excel writer.
# ---> 18         from openpyxl.workbook import Workbook
#      19
#      20         super().__init__(path, mode=mode, **engine_kwargs)
#
# ModuleNotFoundError: No module named 'openpyxl'
